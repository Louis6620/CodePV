# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import stats
from datetime import datetime
dateparse = lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M')
import plotly.express as px
import plotly.graph_objects as go
from mpl_toolkits import mplot3d

# %%
df5 = pd.read_csv('./inv5_emi_data_t345678.csv',
                encoding="utf-8-sig",
                header=0,
                infer_datetime_format=True,
                parse_dates={'datetime':[5]},
                index_col=['datetime']
                )

# %%
df5['time'] = df5.index
df5.loc[:,'year'] = pd.Series(df5.index.year, df5.index)
df5.loc[:,'month'] = pd.Series(df5.index.month, df5.index)
df5.loc[:,'day'] = pd.Series(df5.index.day, df5.index)
df5.loc[:,'hour'] = pd.Series(df5.index.hour, df5.index)
df5.loc[:,'dayofweek'] = pd.Series(df5.index.dayofweek, df5.index)
df5.loc[:,'dayname'] = pd.Series(df5.index.day_name(), df5.index)
df5.loc[:,'hourofweek'] = pd.Series((df5.hour+24*df5.dayofweek), df5.index)
df5.loc[:,'hourofmonth'] = pd.Series((df5.hour+24*(df5.day-1)), df5.index)
df5.loc[:,'Tcell']=pd.Series((df5['Ambient temperature(℃)']+df5['Irradiance(W/㎡)']/800*(25-20)), df5.index)
df5.loc[:,'Pm']=pd.Series((2.172*1.303*220*2*590*df5['Irradiance(W/㎡)']/1000*(1-0.0045*(df5['Tcell']-25))*20.5/100), df5.index)
df5.loc[:,'Hieu suat']=pd.Series((df5['Total input power(kW)']*1000/df5['Pm']*100), df5.index)
df5.head(10)
# Out:
#                      Unnamed: 0.1  Unnamed: 0                Site Name  \
# datetime
# 2022-03-03 14:10:00             0           0  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:15:00             1           1  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:20:00             2           2  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:25:00             3           3  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:30:00             4           4  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:35:00             5           5  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:40:00             6           6  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:45:00             7           7  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:50:00             8           8  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:55:00             9           9  VNM - Đà Nẵng - Nhà Máy
#
#                     Management Domain                 ManageObject_x  \
# datetime
# 2022-03-03 14:10:00       /BCG Energy  1020C0058922/EM001020C0058922
# ...

# %%
df5_1=df5.groupby(['hour','day','month','year'])['Total input power(kW)'].mean()
df5_1=df5_1.reset_index()
df5_1['time']=pd.to_datetime(df5_1[['year','month','day','hour']])
df5_1= df5_1.sort_values('time')
df5_2=df5.groupby(['hour','day','month','year'])['Total input power(kW)'].max()
df5_2=df5_2.reset_index()
df5_2['time']=pd.to_datetime(df5_2[['year','month','day','hour']])
df5_2= df5_2.sort_values('time')
df5_3=df5.groupby(['hour','day','month','year'])['Irradiance(W/㎡)'].mean()
df5_3=df5_3.reset_index()
df5_3['time']=pd.to_datetime(df5_3[['year','month','day','hour']])
df5_3= df5_3.sort_values('time')
df5_4=df5.groupby(['hour','day','month','year'])['Irradiance(W/㎡)'].max()
df5_4=df5_4.reset_index()
df5_4['time']=pd.to_datetime(df5_4[['year','month','day','hour']])
df5_4= df5_4.sort_values('time')
df5_1 = df5_1[df5_1['Total input power(kW)'] > 1]
df5_2 = df5_2[df5_2['Total input power(kW)'] > 1]
df5_3 = df5_3[df5_3['Irradiance(W/㎡)'] > 100]
df5_4 = df5_4[df5_4['Irradiance(W/㎡)'] > 100]
print(df5_1)
print(df5_2)
print(df5_3)
print(df5_4)
# Out:
#       hour  day  month  year  Total input power(kW)                time
# 1790    14    3      3  2022              20.646200 2022-03-03 14:00:00
# 1961    15    3      3  2022              18.346167 2022-03-03 15:00:00
# 2134    16    3      3  2022              20.241750 2022-03-03 16:00:00
# 947      9    4      3  2022              52.755750 2022-03-04 09:00:00
# 1117    10    4      3  2022              97.675000 2022-03-04 10:00:00
# ...    ...  ...    ...   ...                    ...                 ...
# 563      6   25      8  2022               7.609583 2022-08-25 06:00:00
# 735      7   25      8  2022              20.990000 2022-08-25 07:00:00
# 905      8   25      8  2022              48.611000 2022-08-25 08:00:00
# 1075     9   25      8  2022              71.076583 2022-08-25 09:00:00
# 1245    10   25      8  2022              67.671000 2022-08-25 10:00:00
#
# [2076 rows x 6 columns]
#       hour  day  month  year  Total input power(kW)                time
# ...

# %% [markdown]
# Tháng 3

# %% [markdown]
# Trung bình sản lượng điện

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_1.time,
    y=df5_1[df5_1['month']==3]['Total input power(kW)'],
    name="Sản lượng điện trung bình theo khung giờ tháng 3 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Sản lượng điện lớn nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_2.time,
    y=df5_2[df5_2['month']==3]['Total input power(kW)'],
    name="Sản lượng cao nhất theo khung giờ tháng 3 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ trung bình

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_3.time,
    y=df5_3[df5_3['month']==3]['Irradiance(W/㎡)'],
    name="Bức xạ trung bình theo khung giờ tháng 3 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ cao nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_4.time,
    y=df5_4[df5_4['month']==3]['Irradiance(W/㎡)'],
    name="Bức xạ cao nhất theo khung giờ tháng 3 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Tháng 4

# %% [markdown]
# Trung bình sản lượng điện

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_1.time,
    y=df5_1[df5_1['month']==4]['Total input power(kW)'],
    name="Sản lượng điện trung bình theo khung giờ tháng 4 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Sản lượng điện lớn nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_2.time,
    y=df5_2[df5_2['month']==4]['Total input power(kW)'],
    name="Sản lượng cao nhất theo khung giờ tháng 4 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ trung bình

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_3.time,
    y=df5_3[df5_3['month']==4]['Irradiance(W/㎡)'],
    name="Bức xạ trung bình theo khung giờ tháng 4 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ cao nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_4.time,
    y=df5_4[df5_4['month']==4]['Irradiance(W/㎡)'],
    name="Bức xạ cao nhất theo khung giờ tháng 4 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Tháng 5

# %% [markdown]
# Trung bình sản lượng điện

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_1.time,
    y=df5_1[df5_1['month']==5]['Total input power(kW)'],
    name="Sản lượng điện trung bình theo khung giờ tháng 5 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Sản lượng điện lớn nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_2.time,
    y=df5_2[df5_2['month']==5]['Total input power(kW)'],
    name="Sản lượng cao nhất theo khung giờ tháng 5 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ trung bình

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_3.time,
    y=df5_3[df5_3['month']==5]['Irradiance(W/㎡)'],
    name="Bức xạ trung bình theo khung giờ tháng 5 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ cao nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_4.time,
    y=df5_4[df5_4['month']==5]['Irradiance(W/㎡)'],
    name="Bức xạ cao nhất theo khung giờ tháng 5 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Tháng 6

# %% [markdown]
# Trung bình sản lượng điện

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_1.time,
    y=df5_1[df5_1['month']==6]['Total input power(kW)'],
    name="Sản lượng điện trung bình theo khung giờ tháng 6 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Sản lượng điện lớn nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_2.time,
    y=df5_2[df5_2['month']==6]['Total input power(kW)'],
    name="Sản lượng cao nhất theo khung giờ tháng 6 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ trung bình

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_3.time,
    y=df5_3[df5_3['month']==6]['Irradiance(W/㎡)'],
    name="Bức xạ trung bình theo khung giờ tháng 6 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ cao nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_4.time,
    y=df5_4[df5_4['month']==6]['Irradiance(W/㎡)'],
    name="Bức xạ cao nhất theo khung giờ tháng 6 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Tháng 7

# %% [markdown]
# Trung bình sản lượng điện

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_1.time,
    y=df5_1[df5_1['month']==7]['Total input power(kW)'],
    name="Sản lượng điện trung bình theo khung giờ tháng 7 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Sản lượng điện lớn nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_2.time,
    y=df5_2[df5_2['month']==7]['Total input power(kW)'],
    name="Sản lượng cao nhất theo khung giờ tháng 7 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ trung bình

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_3.time,
    y=df5_3[df5_3['month']==7]['Irradiance(W/㎡)'],
    name="Bức xạ trung bình theo khung giờ tháng 7 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ cao nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_4.time,
    y=df5_4[df5_4['month']==7]['Irradiance(W/㎡)'],
    name="Bức xạ cao nhất theo khung giờ tháng 7 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Tháng 8

# %% [markdown]
# Trung bình sản lượng điện

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_1.time,
    y=df5_1[df5_1['month']==8]['Total input power(kW)'],
    name="Sản lượng điện trung bình theo khung giờ tháng 8 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Sản lượng điện lớn nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_2.time,
    y=df5_2[df5_2['month']==8]['Total input power(kW)'],
    name="Sản lượng cao nhất theo khung giờ tháng 8 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ trung bình

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_3.time,
    y=df5_3[df5_3['month']==8]['Irradiance(W/㎡)'],
    name="Bức xạ trung bình theo khung giờ tháng 8 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# Bức xạ cao nhất

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df5_4.time,
    y=df5_4[df5_4['month']==8]['Irradiance(W/㎡)'],
    name="Bức xạ cao nhất theo khung giờ tháng 8 inverter 5 "))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()
