# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import stats
from datetime import datetime
dateparse = lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M')
import plotly.express as px
import plotly.graph_objects as go
from mpl_toolkits import mplot3d

# %%
df1 = pd.read_csv('./inv3_emi_data_t345678.csv',
                encoding="utf-8-sig",
                header=0,
                infer_datetime_format=True,
                parse_dates={'datetime':[5]},
                index_col=['datetime']
                )
df2 = pd.read_csv('./inv4_emi_data_t345678.csv',
                encoding="utf-8-sig",
                header=0,
                infer_datetime_format=True,
                parse_dates={'datetime':[5]},
                index_col=['datetime']
                )

# %%
df1['time'] = df1.index
df1.loc[:,'month'] = pd.Series(df1.index.month, df1.index)
df1.loc[:,'day'] = pd.Series(df1.index.day, df1.index)
df1.loc[:,'hour'] = pd.Series(df1.index.hour, df1.index)
df1.loc[:,'dayofweek'] = pd.Series(df1.index.dayofweek, df1.index)
df1.loc[:,'dayname'] = pd.Series(df1.index.day_name(), df1.index)
df1.loc[:,'hourofweek'] = pd.Series((df1.hour+24*df1.dayofweek), df1.index)
df1.loc[:,'hourofmonth'] = pd.Series((df1.hour+24*(df1.day-1)), df1.index)
df1.loc[:,'Tcell']=pd.Series((df1['Ambient temperature(℃)']+df1['Irradiance(W/㎡)']/800*(25-20)), df1.index)
df1.loc[:,'Pm']=pd.Series((2.172*1.303*220*2*590*df1['Irradiance(W/㎡)']/1000*(1-0.0045*(df1['Tcell']-25))*20.5/100), df1.index)
df1.loc[:,'Hieu suat']=pd.Series((df1['Total input power(kW)']*1000/df1['Pm']*100), df1.index)
df1=df1[df1['Ambient temperature(℃)']>6]
df1.head(100)

df2['time'] = df2.index
df2.loc[:,'month'] = pd.Series(df2.index.month, df2.index)
df2.loc[:,'day'] = pd.Series(df2.index.day, df2.index)
df2.loc[:,'hour'] = pd.Series(df2.index.hour, df2.index)
df2.loc[:,'dayofweek'] = pd.Series(df2.index.dayofweek, df2.index)
df2.loc[:,'dayname'] = pd.Series(df2.index.day_name(), df2.index)
df2.loc[:,'hourofweek'] = pd.Series((df2.hour+24*df2.dayofweek), df2.index)
df2.loc[:,'hourofmonth'] = pd.Series((df2.hour+24*(df2.day-1)), df2.index)
df2.loc[:,'Tcell']=pd.Series((df2['Ambient temperature(℃)']+df2['Irradiance(W/㎡)']/800*(25-20)), df2.index)
df2.loc[:,'Pm']=pd.Series((2.172*1.303*220*2*590*df2['Irradiance(W/㎡)']/1000*(1-0.0045*(df2['Tcell']-25))*20.5/100), df2.index)
df2.loc[:,'Hieu suat']=pd.Series((df2['Total input power(kW)']*1000/df2['Pm']*100), df2.index)
df2=df2[df2['Ambient temperature(℃)']>6]
df2.head(10)
# Out:
#                      Unnamed: 0.1  Unnamed: 0                Site Name  \
# datetime
# 2022-03-03 14:10:00             0           0  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:15:00             1           1  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:20:00             2           2  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:25:00             3           3  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:30:00             4           4  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:35:00             5           5  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:40:00             6           6  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:45:00             7           7  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:50:00             8           8  VNM - Đà Nẵng - Nhà Máy
# 2022-03-03 14:55:00             9           9  VNM - Đà Nẵng - Nhà Máy
#
#                     Management Domain                 ManageObject_x  \
# datetime
# 2022-03-03 14:10:00       /BCG Energy  1020C0058922/EM001020C0058922
# ...

# %%
df1_1=df1.groupby(['hour'])['Total input power(kW)'].mean()
df1_1=df1_1.reset_index()
df1_2=df1.groupby(['hour'])['Total input power(kW)'].max()
df1_2=df1_2.reset_index()
fig = go.Figure()
from plotly.subplots import make_subplots
fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Bar(
    x=df1_1.index,
    y=df1_1['Total input power(kW)'],
    text=round(df1_1['Total input power(kW)']),  # Set the text to the values of y
    textposition='auto',
    name="Sản lượng điện trung bình theo khung giờ của inv 3",
), row=1, col=1)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.add_trace(go.Bar(
    x=df1_2.index,
    y=df1_2['Total input power(kW)'],
    name="Sản lượng điện cao nhất theo khung giờ của inv 3",
    text=round(df1_2['Total input power(kW)']),  # Set the text to the values of y
    textposition='auto',
) ,row=1, col=2)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %%
df2_1=df2.groupby(['hour'])['Total input power(kW)'].mean()
df2_1=df2_1.reset_index()
df2_2=df2.groupby(['hour'])['Total input power(kW)'].max()
df2_2=df2_2.reset_index()
fig = go.Figure()
from plotly.subplots import make_subplots
fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Bar(
    x=df2_1.index,
    y=df2_1['Total input power(kW)'],
    text=round(df2_1['Total input power(kW)']),  # Set the text to the values of y
    textposition='auto',
    name="Sản lượng điện trung bình theo khung giờ của inv 4",
), row=1, col=1)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.add_trace(go.Bar(
    x=df2_2.index,
    y=df2_2['Total input power(kW)'],
    name="Sản lượng điện cao nhất theo khung giờ của inv 4",
    text=round(df2_2['Total input power(kW)']),  # Set the text to the values of y
    textposition='auto',
) ,row=1, col=2)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %%
df1_1=df1.groupby(['hour'])['Irradiance(W/㎡)'].mean()
df1_1=df1_1.reset_index()
df1_2=df1.groupby(['hour'])['Irradiance(W/㎡)'].max()
df1_2=df1_2.reset_index()
fig = go.Figure()
from plotly.subplots import make_subplots
fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Bar(
    x=df1_1.index,
    y=df1_1['Irradiance(W/㎡)'],
    text=round(df1_1['Irradiance(W/㎡)']),  # Set the text to the values of y
    textposition='auto',
    name="Irradiance trung bình theo khung giờ của inv 3",
), row=1, col=1)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.add_trace(go.Bar(
    x=df1_2.index,
    y=df1_2['Irradiance(W/㎡)'],
    name="Irradiance cao nhất theo khung giờ của inv 3",
    text=round(df1_2['Irradiance(W/㎡)']),  # Set the text to the values of y
    textposition='auto',
) ,row=1, col=2)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %%
i=3
while i<=8:
    c=str(i)
    df1_1=df1.groupby(['month','hour'])['Irradiance(W/㎡)'].mean()
    df1_1=df1_1.reset_index()
    df1_2=df1.groupby(['month','hour'])['Irradiance(W/㎡)'].max()
    df1_2=df1_2.reset_index()
    df1_1=df1_1[df1_1['month']==i]
    df1_1=df1_1.reset_index()
    df1_2=df1_2[df1_2['month']==i]
    df1_2=df1_2.reset_index()
    fig = go.Figure()
    from plotly.subplots import make_subplots
    fig = make_subplots(rows=1, cols=2)
    fig.add_trace(go.Bar(
        x=df1_1.index,
        y=df1_1['Irradiance(W/㎡)'],
        text=round(df1_1['Irradiance(W/㎡)']),  # Set the text to the values of y
        textposition='auto',
        name="Irradiance trung bình theo khung giờ của inv 3 trong thang "+c,
    ), row=1, col=1)
    fig . update_traces (
        showlegend = True 
        )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.add_trace(go.Bar(
        x=df1_2.index,
        y=df1_2['Irradiance(W/㎡)'],
        name="Irradiance cao nhất theo khung giờ của inv 3 trong thang "+c,
        text=round(df1_2['Irradiance(W/㎡)']),  # Set the text to the values of y
        textposition='auto',
    ) ,row=1, col=2)
    fig . update_traces (
        showlegend = True 
        )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1

# %%
i=3
while i<=8:
    c=str(i)
    df1_1=df2.groupby(['month','hour'])['Irradiance(W/㎡)'].mean()
    df1_1=df1_1.reset_index()
    df1_2=df2.groupby(['month','hour'])['Irradiance(W/㎡)'].max()
    df1_2=df1_2.reset_index()
    df1_1=df1_1[df1_1['month']==i]
    df1_1=df1_1.reset_index()
    df1_2=df1_2[df1_2['month']==i]
    df1_2=df1_2.reset_index()
    fig = go.Figure()
    from plotly.subplots import make_subplots
    fig = make_subplots(rows=1, cols=2)
    fig.add_trace(go.Bar(
        x=df1_1.index,
        y=df1_1['Irradiance(W/㎡)'],
        text=round(df1_1['Irradiance(W/㎡)']),  # Set the text to the values of y
        textposition='auto',
        name="Irradiance trung bình theo khung giờ của inv 4 trong thang "+c,
    ), row=1, col=1)
    fig . update_traces (
        showlegend = True 
        )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.add_trace(go.Bar(
        x=df1_2.index,
        y=df1_2['Irradiance(W/㎡)'],
        name="Irradiance cao nhất theo khung giờ của inv 4 trong thang "+c,
        text=round(df1_2['Irradiance(W/㎡)']),  # Set the text to the values of y
        textposition='auto',
    ) ,row=1, col=2)
    fig . update_traces (
        showlegend = True 
        )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1

# %%
df2_1=df2.groupby(['hour'])['Irradiance(W/㎡)'].mean()
df2_1=df2_1.reset_index()
df2_2=df2.groupby(['hour'])['Irradiance(W/㎡)'].max()
df2_2=df2_2.reset_index()
fig = go.Figure()
from plotly.subplots import make_subplots
fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Bar(
    x=df2_1.index,
    y=df2_1['Irradiance(W/㎡)'],
    text=round(df2_1['Irradiance(W/㎡)']),  # Set the text to the values of y
    textposition='auto',
    name="Irradiance trung bình theo khung giờ của inv 4",
), row=1, col=1)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.add_trace(go.Bar(
    x=df2_2.index,
    y=df2_2['Irradiance(W/㎡)'],
    name="Irradiance cao nhất theo khung giờ của inv 4",
    text=round(df2_2['Irradiance(W/㎡)']),  # Set the text to the values of y
    textposition='auto',
) ,row=1, col=2)
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %%
df1_3=df1.groupby(['month','day'])['Hieu suat'].max()
df1_3=df1_3.reset_index()
df1_3=df1_3[df1_3['Hieu suat']<100]
df1_3=df1_3[df1_3['Hieu suat']>0]
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df1_3.index,
    y=df1_3['Hieu suat'],
    name="Hieu suat cao nhat moi ngay cua inv 3",
    mode="lines+markers"
))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %%
i=3
while i<=8:
    c=str(i)
    df1_3=df1.groupby(['month','day'])['Hieu suat'].max()
    df1_3=df1_3.reset_index()
    df1_3=df1_3[df1_3['Hieu suat']<100]
    df1_3=df1_3[df1_3['Hieu suat']>0]
    df1_3=df1_3[df1_3['month']==i]
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df1_3.index,
        y=df1_3['Hieu suat'],
        name="Hieu suat cao nhat moi ngay cua inverter 3 trong thang "+c,
        mode="lines+markers"
    ))
    fig . update_traces (
    showlegend = True 
    )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1

# %%
df2_3=df2.groupby(['month','day'])['Hieu suat'].max()
df2_3=df2_3.reset_index()
df2_3=df2_3[df2_3['Hieu suat']<100]
df2_3=df2_3[df2_3['Hieu suat']>0]
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df2_3.index,
    y=df2_3['Hieu suat'],
    name="Hieu suat cao nhat moi ngay cua inv 4",
    mode="lines+markers"
))
fig . update_traces (
    showlegend = True 
    )
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %%
i=3
while i<=8:
    c=str(i)
    df2_3=df2.groupby(['month','day'])['Hieu suat'].max()
    df2_3=df2_3.reset_index()
    df2_3=df2_3[df2_3['Hieu suat']<100]
    df2_3=df2_3[df2_3['Hieu suat']>0]
    df2_3=df2_3[df2_3['month']==i]
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df2_3.index,
        y=df2_3['Hieu suat'],
        name="Hieu suat cao nhat moi ngay cua inverter 4 trong thang "+c,
        mode="lines+markers"
    ))
    fig . update_traces (
    showlegend = True 
    )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1

# %%
i=3
while i<=8:
    c=str(i)
    df1_4=df1.groupby(['month','hour'])['Hieu suat'].mean()
    df1_4=df1_4.reset_index()
    df1_4=df1_4[df1_4['month']==i]
    fig = go.Figure()
    fig.add_trace(go.Bar(
        x=df1_4['hour'],
        y=df1_4['Hieu suat'],
        text=round(df1_4['Hieu suat']),  # Set the text to the values of y
        textposition='auto',
        name="Hiệu suất trung bình theo khung giờ của inv 3 trong tháng "+c,
    ))
    fig . update_traces (
        showlegend = True 
        )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1

# %%
i=3
while i<=8:
    c=str(i)
    df1_4=df2.groupby(['month','hour'])['Hieu suat'].mean()
    df1_4=df1_4.reset_index()
    df1_4=df1_4[df1_4['month']==i]
    fig = go.Figure()
    fig.add_trace(go.Bar(
        x=df1_4['hour'],
        y=df1_4['Hieu suat'],
        text=round(df1_4['Hieu suat']),  # Set the text to the values of y
        textposition='auto',
        name="Hiệu suất trung bình theo khung giờ của inv 4 trong tháng "+c,
    ))
    fig . update_traces (
        showlegend = True 
        )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1

# %%
i=3
while i<=8:
    c=str(i)
    df1_3=df1.groupby(['month','day'])['Hieu suat'].mean()
    df1_3=df1_3.reset_index()
    df1_3=df1_3[df1_3['Hieu suat']<100]
    df1_3=df1_3[df1_3['Hieu suat']>0]
    df1_3=df1_3[df1_3['month']==i]
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df1_3.index,
        y=df1_3['Hieu suat'],
        name="Hieu suat trung binh moi ngay cua inverter 3 trong thang "+c,
        mode="lines+markers"
    ))
    fig . update_traces (
    showlegend = True 
    )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1

# %%
i=3
while i<=8:
    c=str(i)
    df1_3=df2.groupby(['month','day'])['Hieu suat'].mean()
    df1_3=df1_3.reset_index()
    df1_3=df1_3[df1_3['Hieu suat']<100]
    df1_3=df1_3[df1_3['Hieu suat']>0]
    df1_3=df1_3[df1_3['month']==i]
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df1_3.index,
        y=df1_3['Hieu suat'],
        name="Hieu suat trung binh moi ngay cua inverter 4 trong thang "+c,
        mode="lines+markers"
    ))
    fig . update_traces (
    showlegend = True 
    )
    fig.update_xaxes(
        rangeslider_visible=True,
    )
    fig.show()
    i=i+1
