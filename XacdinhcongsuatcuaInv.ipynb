# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import seaborn as sns
import datetime
import plotly.graph_objects as go
import excel
import plotly.express as px

# %%
df = pd.read_excel('D:\OneDrive - Hanoi University of Science and Technology\Me\Code\DatainHUST\CodePV\Bank_Stocks.xlsx', 
                     header=0,
                     parse_dates={'datetime':[4]},
                     index_col='datetime')

# %%
df['time']=df.index
df['month'] = df.index.month
df['day'] = df.index.day
df['hour'] = df.index.hour
df['year'] = df.index.year
df['dayofweek'] = df.index.dayofweek
df['dayname'] = df.index.day_name()
df['hourofweek'] = (df.hour+24*df.dayofweek)
df['hourofmonth'] = (df.hour+24*(df.day-1))
df['Tiền điện FIT 1']= (1938*df['Annual energy(kWh)'])
df['Stt'] = range(len(df))
df.head()
# Out:
#                      Unnamed: 0                Site Name Management Domain  \
# datetime
# 2022-03-03 14:10:00           0  VNM - Đà Nẵng - Nhà Máy       /BCG Energy
# 2022-03-03 14:15:00           1  VNM - Đà Nẵng - Nhà Máy       /BCG Energy
# 2022-03-03 14:20:00           2  VNM - Đà Nẵng - Nhà Máy       /BCG Energy
# 2022-03-03 14:25:00           3  VNM - Đà Nẵng - Nhà Máy       /BCG Energy
# 2022-03-03 14:30:00           4  VNM - Đà Nẵng - Nhà Máy       /BCG Energy
#
#                                     ManageObject_x  Ambient temperature(℃)  \
# datetime
# 2022-03-03 14:10:00  1020C0058922/EM001020C0058922                    25.1
# 2022-03-03 14:15:00  1020C0058922/EM001020C0058922                    25.0
# 2022-03-03 14:20:00  1020C0058922/EM001020C0058922                    24.7
# 2022-03-03 14:25:00  1020C0058922/EM001020C0058922                    24.6
# 2022-03-03 14:30:00  1020C0058922/EM001020C0058922                    24.7
#
# ...

# %%
df['Daily Value'] = df['Annual energy(kWh)'].sub(df['Annual energy(kWh)'].shift())
df['Annual energy(kWh)'].iloc[0] = df['Daily Value'].iloc[0]
print (df['Daily Value'])
# Out:
# datetime
# 2022-03-03 14:10:00     NaN
# 2022-03-03 14:15:00     NaN
# 2022-03-03 14:20:00     NaN
# 2022-03-03 14:25:00     NaN
# 2022-03-03 14:30:00     NaN
#                        ...
# 2022-08-25 10:10:00    4.90
# 2022-08-25 10:15:00    4.99
# 2022-08-25 10:20:00    5.35
# 2022-08-25 10:25:00    5.50
# 2022-08-25 10:30:00    5.76
# Name: Daily Value, Length: 27617, dtype: float64
# C:\Users\badao\AppData\Local\Temp\ipykernel_19144\432568576.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.bar(df, x=df.index, y='Daily Value',title='Công suất thu được')
fig.update_xaxes(
    rangeslider_visible=True,
    ##thanh kéo##
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1d", step="day", stepmode="backward"),
            dict(count=7, label="1w", step="day", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
