# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import stats
from datetime import datetime
dateparse = lambda x: datetime.strptime(x, '%m/%d/%Y %H:%M')
import plotly.express as px
import plotly.graph_objects as go
import excel
import glob
import os

# %%
avg = df['Irradiance(W/㎡)'].mean()
df['avg']=avg
print(avg)
fig = go.Figure()
fig.add_trace(go.Scatter(
    x= df.time,
    y= df['tiền điện 5p 1 lần']/1000,
    name = 'Tiền điện FIT 1 5p 1 lần (*1000VND)', 
    yaxis= 'y'
))
fig.add_trace(go.Scatter(
    x= df.time,
    y= df['Daily Value'],
    name = 'KWH per min',
    yaxis= 'y'
))
fig.update_traces(
    hoverinfo='name+x+y+text',
    line={'width':2},
    marker = {"size":5},
    mode = 'lines',
    showlegend =True
)
fig.update_xaxes(
    rangeslider_visible=True
)
fig.show()
# Out:
# 391.71077235036387
